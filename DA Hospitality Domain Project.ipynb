# %% [markdown]
# # Data Exploration

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_bookings.csv")
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot()
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min()
# Out:
# 6500

# %%
df_bookings.revenue_generated.max()
# Out:
# 28560000

# %%
df_date = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\dim_date.csv")
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_date.head(5)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date.day_type.unique()
# Out:
# array(['weekend', 'weekeday'], dtype=object)

# %%
df_hotels = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\dim_hotels.csv")
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df_hotels.head(7)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi
# 5        16563   Atliq Palace  Business   Delhi
# 6        17558   Atliq Grands    Luxury  Mumbai

# %%
df_hotels.category.unique()
# Out:
# array(['Luxury', 'Business'], dtype=object)

# %%
df_hotels.property_name.unique()
# Out:
# array(['Atliq Grands', 'Atliq Exotica', 'Atliq City', 'Atliq Blu',
#        'Atliq Bay', 'Atliq Palace', 'Atliq Seasons'], dtype=object)

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.describe()
# Out:
#         property_id
# count     25.000000
# mean   18040.640000
# std     1122.436371
# min    16558.000000
# 25%    17558.000000
# 50%    17564.000000
# 75%    18563.000000
# max    19563.000000

# %%
df_hotels.property_name.value_counts()
# Out:
# property_name
# Atliq Grands     4
# Atliq Exotica    4
# Atliq City       4
# Atliq Blu        4
# Atliq Bay        4
# Atliq Palace     4
# Atliq Seasons    1
# Name: count, dtype: int64

# %%
df_rooms = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\dim_rooms.csv")
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_aggr_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_aggregated_bookings.csv")
df_aggr_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_aggr_bookings.head(10)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
# 6        19558      1-May-22           RT1                   25      40.0
# 7        19560      1-May-22           RT1                   23      26.0
# 8        17561      1-May-22           RT1                   22       NaN
# 9        16560      1-May-22           RT1                   24      34.0

# %%
# Q.Find out unique property ids in aggregate bookings dataset?

df_aggr_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %%
# Q.Find out total bookings per property_id?

df_aggr_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
# Q. Find out days on which bookings are greater than capacity?

df_aggr_bookings[df_aggr_bookings.successful_bookings>df_aggr_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
# Q. Find out properties that have highest capacity?

df_aggr_bookings.capacity.max()
df_aggr_bookings[df_aggr_bookings.capacity==df_aggr_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_bookings.csv")
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
# Clean invalid guests

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
# Outliner removal in revenue generated

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.median()
# Out:
# (15378.036937686695, 13500.0)

# %%
avg,std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -263742.4278566132

# %%
df_bookings[df_bookings.revenue_generated<=0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings[df_bookings.revenue_generated<=higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134578.000000
# mean      12696.011822
# std        6927.841641
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33479.53674501789

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
# mean + 3*standard deviation
23439+3*9048
# Out:
# 50583

# %%
df_bookings[df_bookings.booking_id=="May012216558RT213"]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77899
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
# Q. In aggregate bookings find columns that have null values. Fill these null values with whatever you think is the appropriate subtitute 
     #(possible ways is to use mean or median)?
# Out:
#   Cell In[36], line 4
#     df_aggr_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_aggregated_bookings.csv")
#     ^
# IndentationError: unexpected indent

# %%
df_aggr_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_aggregated_bookings.csv")
df_aggr_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_aggr_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_aggr_bookings[df_aggr_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_aggr_bookings.capacity.median()
# Out:
# 25.0

# %%
df_aggr_bookings.capacity.fillna(df_aggr_bookings.capacity.median(), inplace=True)

# %%
df_aggr_bookings.loc[[8,15]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 15        17563      1-May-22           RT1                   21      25.0

# %%
 #Q. In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records?

# %%
df_aggr_bookings[df_aggr_bookings.successful_bookings>df_aggr_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_aggr_bookings.shape
# Out:
# (9200, 5)

# %%
df_aggr_bookings = df_aggr_bookings[df_aggr_bookings.successful_bookings<=df_aggr_bookings.capacity]
df_aggr_bookings.shape
# Out:
# (9194, 5)

# %% [markdown]
# # Data Transformation

# %%
df_aggr_bookings.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_aggr_bookings.head(5)
#
# NameError: name 'df_aggr_bookings' is not defined

# %%
df_aggr_bookings['occ_pct'] = df_aggr_bookings.apply(lambda row: row['successful_bookings']/row['capacity'], axis = 1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11984\2190767849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aggr_bookings['occ_pct'] = df_aggr_bookings.apply(lambda row: row['successful_bookings']/row['capacity'], axis = 1)

# %%
new_col = df_aggr_bookings.apply(lambda row: row['successful_bookings']/row['capacity'], axis=1)
df_aggr_bookings = df_aggr_bookings.assign(occ_pct=new_col.values)
df_aggr_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667

# %%
# Convert into percentage value

# %%
df_aggr_bookings['occ_pct'] = df_aggr_bookings['occ_pct'].apply(lambda x: round(x*100, 2))
df_aggr_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# ...

# %%
df_aggr_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9194 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9194 non-null   int64
#  1   check_in_date        9194 non-null   object
#  2   room_category        9194 non-null   object
#  3   successful_bookings  9194 non-null   int64
#  4   capacity             9194 non-null   float64
#  5   occ_pct              9194 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 502.8+ KB

# %% [markdown]
# # Insights Generation

# %%
import pandas as pd

# %%
df_date = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\dim_date.csv")
df_date.head(5)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_bookings.csv")
df_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\dim_hotels.csv")
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_rooms = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\dim_rooms.csv")
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_aggr_bookings = pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\fact_aggregated_bookings.csv")
df_aggr_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %% [markdown]
#  1. What is an average occupancy rate in each of the room categories?

# %%
new_col = df_aggr_bookings.apply(lambda row: row['successful_bookings']/row['capacity'], axis=1)
df_aggr_bookings = df_aggr_bookings.assign(occ_pct=new_col.values)

# %%
df_aggr_bookings['occ_pct'] = df_aggr_bookings['occ_pct'].apply(lambda x: round(x*100, 2))
df_aggr_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %%
df_aggr_bookings.groupby("room_category")["occ_pct"].mean()
# Out:
# room_category
# RT1    58.224247
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occ_pct, dtype: float64

# %%
df = pd.merge(df_aggr_bookings,df_rooms,left_on = "room_category",right_on = "room_id")

df.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard
# 4    94.74     RT1   Standard

# %%
df.groupby("room_category")["occ_pct"].mean()
# Out:
# room_category
# RT1    58.224247
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occ_pct, dtype: float64

# %%
df.drop("room_category",axis=1, inplace=True)
df.head(5)
# Out:
#    property_id check_in_date  successful_bookings  capacity  occ_pct  \
# 0        16559      1-May-22                   25      30.0    83.33
# 1        19562      1-May-22                   28      30.0    93.33
# 2        19563      1-May-22                   23      30.0    76.67
# 3        17558      1-May-22                   30      19.0   157.89
# 4        16558      1-May-22                   18      19.0    94.74
#
#   room_class
# 0   Standard
# 1   Standard
# 2   Standard
# 3   Standard
# 4   Standard

# %%
df.groupby("room_class")["occ_pct"].mean()
# Out:
# room_class
# Elite           58.040278
# Premium         58.028213
# Presidential    59.300461
# Standard        58.224247
# Name: occ_pct, dtype: float64

# %%
df[df.room_class=="Standard"].occ_pct.mean()
# Out:
# 58.22424717145344

# %% [markdown]
# 2. Print average occupancy rate per city?

# %%
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df,df_hotels,on="property_id")
df.head(5)
# Out:
#    property_id check_in_date  successful_bookings  capacity  occ_pct  \
# 0        16559      1-May-22                   25      30.0    83.33
# 1        16559      2-May-22                   20      30.0    66.67
# 2        16559      3-May-22                   17      30.0    56.67
# 3        16559      4-May-22                   21      30.0    70.00
# 4        16559      5-May-22                   16      30.0    53.33
#
#   room_class  property_name category    city
# 0   Standard  Atliq Exotica   Luxury  Mumbai
# 1   Standard  Atliq Exotica   Luxury  Mumbai
# 2   Standard  Atliq Exotica   Luxury  Mumbai
# 3   Standard  Atliq Exotica   Luxury  Mumbai
# 4   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby("city")["occ_pct"].mean()
# Out:
# city
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.936305
# Name: occ_pct, dtype: float64

# %%
df.groupby("city")["occ_pct"].mean().sort_values()
# Out:
# city
# Bangalore    56.594207
# Mumbai       57.936305
# Hyderabad    58.144651
# Delhi        61.606467
# Name: occ_pct, dtype: float64

# %%
df.groupby("city")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df.groupby("city")["occ_pct"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# 3. When was the occupancy better? Weekday or Weekend?

# %%
df_date.head(5)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df = pd.merge(df,df_date,left_on="check_in_date",right_on="date")

df.head(5)
# Out:
#    property_id check_in_date  successful_bookings  capacity  occ_pct  \
# 0        16559     10-May-22                   18      30.0    60.00
# 1        16559     10-May-22                   25      41.0    60.98
# 2        16559     10-May-22                   20      32.0    62.50
# 3        16559     10-May-22                   13      18.0    72.22
# 4        19562     10-May-22                   18      30.0    60.00
#
#      room_class  property_name category       city       date  mmm yy week no  \
# 0      Standard  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22    W 20
# 1         Elite  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22    W 20
# 2       Premium  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22    W 20
# 3  Presidential  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22    W 20
# 4      Standard      Atliq Bay   Luxury  Bangalore  10-May-22  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday
# 3  weekeday
# 4  weekeday

# %%
df.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %% [raw]
# 4: In the month of June, what is the occupancy for different cities

# %%
df_june_22 = df[df["mmm yy"]=="Jun 22"]

df_june_22.head(5)
# Out:
#       property_id check_in_date  successful_bookings  capacity  occ_pct  \
# 2200        16559     10-Jun-22                   20      30.0    66.67
# 2201        16559     10-Jun-22                   26      41.0    63.41
# 2202        16559     10-Jun-22                   20      32.0    62.50
# 2203        16559     10-Jun-22                   11      18.0    61.11
# 2204        19562     10-Jun-22                   19      30.0    63.33
#
#         room_class  property_name category       city       date  mmm yy  \
# 2200      Standard  Atliq Exotica   Luxury     Mumbai  10-Jun-22  Jun 22
# 2201         Elite  Atliq Exotica   Luxury     Mumbai  10-Jun-22  Jun 22
# 2202       Premium  Atliq Exotica   Luxury     Mumbai  10-Jun-22  Jun 22
# 2203  Presidential  Atliq Exotica   Luxury     Mumbai  10-Jun-22  Jun 22
# 2204      Standard      Atliq Bay   Luxury  Bangalore  10-Jun-22  Jun 22
#
#      week no  day_type
# 2200    W 24  weekeday
# 2201    W 24  weekeday
# ...

# %%
df_june_22.groupby("city")["occ_pct"].mean().sort_values()
# Out:
# city
# Bangalore    56.578552
# Mumbai       58.382560
# Hyderabad    58.458075
# Delhi        62.474286
# Name: occ_pct, dtype: float64

# %%
df_june_22.groupby("city")["occ_pct"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [raw]
# 5: We got new data for the month of august. Append that to existing data

# %%
df_august= pd.read_csv("C:\\Users\\Admin\\Desktop\\CODEBASICS\\Basic Pyrhon\\source-code\\source-code\\3_project_hospitality_analysis\\datasets\\new_data_august.csv")

df_august.head(5)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'successful_bookings', 'capacity',
#        'occ_pct', 'room_class', 'property_name', 'category', 'city', 'date',
#        'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 13)

# %%
latest_df=pd.concat([df,df_august],ignore_index=True,axis=0)

latest_df.tail(10)
# Out:
#       property_id check_in_date  successful_bookings  capacity  occ_pct  \
# 6497        18560     31-Jul-22                   34      40.0    85.00
# 6498        18560     31-Jul-22                   17      24.0    70.83
# 6499        18560     31-Jul-22                   12      15.0    80.00
# 6500        16559     01-Aug-22                   30      30.0      NaN
# 6501        19562     01-Aug-22                   21      30.0      NaN
# 6502        19563     01-Aug-22                   23      30.0      NaN
# 6503        19558     01-Aug-22                   30      40.0      NaN
# 6504        19560     01-Aug-22                   20      26.0      NaN
# 6505        17561     01-Aug-22                   18      26.0      NaN
# 6506        17564     01-Aug-22                   10      16.0      NaN
#
#         room_class  property_name  category       city       date  mmm yy  \
# 6497         Elite     Atliq City  Business  Hyderabad  31-Jul-22  Jul 22
# ...

# %%
latest_df.shape
# Out:
# (6507, 15)

# %% [raw]
# 6. Print revenue realized per city?

# %%
df_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings_all= pd.merge(df_bookings,df_hotels, on="property_id")

df_bookings_all.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420397050
# Delhi        294500318
# Hyderabad    325232870
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum().sort_values()
# Out:
# city
# Delhi        294500318
# Hyderabad    325232870
# Bangalore    420397050
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %% [raw]
# 7. Print month by month revenue?

# %%
df_date.head(5)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_bookings_all.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"] = pd.to_datetime(df_date["date"])

df_date.head(5)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday
# 3 2022-05-04  May 22    W 19  weekeday
# 4 2022-05-05  May 22    W 19  weekeday

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
#  12  property_name      134590 non-null  object
#  13  category           134590 non-null  object
#  14  city               134590 non-null  object
# ...

# %% [raw]
# Exercise-1. Print revenue realized per hotel type?

# %%
df_bookings_all.property_name.unique()
# Out:
# array(['Atliq Grands', 'Atliq Exotica', 'Atliq City', 'Atliq Blu',
#        'Atliq Bay', 'Atliq Palace', 'Atliq Seasons'], dtype=object)

# %%
df_bookings_all.groupby("property_name")["revenue_realized"].sum().round(2).sort_values()
# Out:
# property_name
# Atliq Seasons     66125495
# Atliq Grands     211532764
# Atliq Bay        260051178
# Atliq Blu        260855522
# Atliq City       285811939
# Atliq Palace     304081863
# Atliq Exotica    320312468
# Name: revenue_realized, dtype: int64

# %%
Exercise-2 Print average rating per city?

# %%
df_bookings_all.groupby("city")["ratings_given"].mean().round(2)
# Out:
# city
# Bangalore    3.41
# Delhi        3.78
# Hyderabad    3.66
# Mumbai       3.65
# Name: ratings_given, dtype: float64

# %%
Exercise-3 Print a pie chart of revenue realized per booking platform?

# %%
df_bookings_all.groupby("booking_platform")["revenue_realized"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='revenue_realized'>
